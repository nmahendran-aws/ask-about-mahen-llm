# %%
print("Hello World")
# Out:
# Hello World

# %%
from bedrock_agentcore_starter_toolkit import Runtime
from boto3.session import Session
boto_session = Session()
region = boto_session.region_name

agentcore_runtime = Runtime()
agent_name = "ask_about_mahen_agentcore"
response = agentcore_runtime.configure(
    entrypoint="server.py",
    auto_create_execution_role=True,
    auto_create_ecr=True,
    requirements_file="requirements.txt",
    region=region,
    agent_name=agent_name
)
response
# Out:
# Entrypoint parsed: file=/Users/mahen/learnings/AI/ai-agent/ask-about-mahen-llm/backend/server.py, bedrock_agentcore_name=server
# Configuring BedrockAgentCore agent: ask_about_mahen_agentcore
# ⚠️  ℹ️  No container engine found (Docker/Finch/Podman not installed)
# ✅ Default deployment uses CodeBuild (no container engine needed)
# 💡 Run 'agentcore launch' for cloud-based building and deployment
# 💡 For local builds, install Docker, Finch, or Podman
# ⚠️  [WARNING] Platform mismatch: Current system is 'linux/amd64' but Bedrock AgentCore requires 'linux/arm64'.
# For deployment options and workarounds, see:
# https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/getting-started-custom.html
# Generated .dockerignore
# Generated Dockerfile: /Users/mahen/learnings/AI/ai-agent/ask-about-mahen-llm/backend/Dockerfile
# Generated .dockerignore: /Users/mahen/learnings/AI/ai-agent/ask-about-mahen-llm/backend/.dockerignore
# Setting 'ask_about_mahen_agentcore' as default agent
# Bedrock AgentCore configured: /Users/mahen/learnings/AI/ai-agent/ask-about-mahen-llm/backend/.bedrock_agentcore.yaml
# ConfigureResult(config_path=PosixPath('/Users/mahen/learnings/AI/ai-agent/ask-about-mahen-llm/backend/.bedrock_agentcore.yaml'), dockerfile_path=PosixPath('/Users/mahen/learnings/AI/ai-agent/ask-about-mahen-llm/backend/Dockerfile'), dockerignore_path=PosixPath('/Users/mahen/learnings/AI/ai-agent/ask-about-mahen-llm/backend/.dockerignore'), runtime='None', region='us-east-1', account_id='471727841202', execution_role=None, ecr_repository=None, auto_create_ecr=True)

# %%
launch_result = agentcore_runtime.launch()
print(launch_result)
# Out:
# 🚀 CodeBuild mode: building in cloud (RECOMMENDED - DEFAULT)
#    • Build ARM64 containers in the cloud with CodeBuild
#    • No local Docker required
# 💡 Available deployment modes:
#    • runtime.launch()                           → CodeBuild (current)
#    • runtime.launch(local=True)                 → Local development
#    • runtime.launch(local_build=True)           → Local build + cloud deploy (NEW)
# Starting CodeBuild ARM64 deployment for agent 'ask_about_mahen_agentcore' to account 471727841202 (us-east-1)
# Setting up AWS resources (ECR repository, execution roles)...
# Using ECR repository from config: 471727841202.dkr.ecr.us-east-1.amazonaws.com/bedrock-agentcore-ask_about_mahen_agentcore
# Using execution role from config: arn:aws:iam::471727841202:role/AmazonBedrockAgentCoreSDKRuntime-us-east-1-83f1e37868
# Preparing CodeBuild project and uploading source...
# Using CodeBuild role from config: arn:aws:iam::471727841202:role/AmazonBedrockAgentCoreSDKCodeBuild-us-east-1-83f1e37868
# Using .dockerignore with 44 patterns
# Uploaded source to S3: ask_about_mahen_agentcore/source.zip
# Using CodeBuild project from config: bedrock-agentcore-ask_about_mahen_agentcore-builder
# Starting CodeBuild build (this may take several minutes)...
# Starting CodeBuild monitoring...
# 🔄 QUEUED started (total: 0s)
# ✅ QUEUED completed in 1.2s
# 🔄 PROVISIONING started (total: 1s)
# ✅ PROVISIONING completed in 8.7s
# 🔄 DOWNLOAD_SOURCE started (total: 10s)
# ✅ DOWNLOAD_SOURCE completed in 2.2s
# 🔄 BUILD started (total: 12s)
# ✅ BUILD completed in 19.7s
# 🔄 POST_BUILD started (total: 32s)
# ✅ POST_BUILD completed in 13.1s
# 🔄 COMPLETED started (total: 45s)
# ✅ COMPLETED completed in 1.1s
# 🎉 CodeBuild completed successfully in 0m 46s
# CodeBuild completed successfully
# ✅ CodeBuild project configuration saved
# Deploying to Bedrock AgentCore...
# ✅ Agent created/updated: arn:aws:bedrock-agentcore:us-east-1:471727841202:runtime/ask_about_mahen_agentcore-OQ0yZ9D9E0
# Observability is enabled, configuring Transaction Search...
# CloudWatch Logs resource policy already configured
# X-Ray trace destination already configured
# X-Ray indexing rule already configured
# ✅ Transaction Search already fully configured
# 🔍 GenAI Observability Dashboard:
#    https://console.aws.amazon.com/cloudwatch/home?region=us-east-1#gen-ai-observability/agent-core
# Polling for endpoint to be ready...
# Agent endpoint: arn:aws:bedrock-agentcore:us-east-1:471727841202:runtime/ask_about_mahen_agentcore-OQ0yZ9D9E0/runtime-endpoint/DEFAULT
# Deployment completed successfully - Agent: arn:aws:bedrock-agentcore:us-east-1:471727841202:runtime/ask_about_mahen_agentcore-OQ0yZ9D9E0
# Built with CodeBuild: bedrock-agentcore-ask_about_mahen_agentcore-builder:09c3a035-5b9c-4777-a56d-06ff1b6b45f8
# Deployed to cloud: arn:aws:bedrock-agentcore:us-east-1:471727841202:runtime/ask_about_mahen_agentcore-OQ0yZ9D9E0
# ECR image: 471727841202.dkr.ecr.us-east-1.amazonaws.com/bedrock-agentcore-ask_about_mahen_agentcore
# 🔍 Agent logs available at:
#    /aws/bedrock-agentcore/runtimes/ask_about_mahen_agentcore-OQ0yZ9D9E0-DEFAULT --log-stream-name-prefix "2025/12/09/\[runtime-logs]"
#    /aws/bedrock-agentcore/runtimes/ask_about_mahen_agentcore-OQ0yZ9D9E0-DEFAULT --log-stream-names "otel-rt-logs"
# 💡 Tail logs with: aws logs tail /aws/bedrock-agentcore/runtimes/ask_about_mahen_agentcore-OQ0yZ9D9E0-DEFAULT --log-stream-name-prefix "2025/12/09/\[runtime-logs]" --follow
# 💡 Or view recent logs: aws logs tail /aws/bedrock-agentcore/runtimes/ask_about_mahen_agentcore-OQ0yZ9D9E0-DEFAULT --log-stream-name-prefix "2025/12/09/\[runtime-logs]" --since 1h
# mode='codebuild' tag='bedrock_agentcore-ask_about_mahen_agentcore:latest' env_vars=None port=None runtime=None ecr_uri='471727841202.dkr.ecr.us-east-1.amazonaws.com/bedrock-agentcore-ask_about_mahen_agentcore' agent_id='ask_about_mahen_agentcore-OQ0yZ9D9E0' agent_arn='arn:aws:bedrock-agentcore:us-east-1:471727841202:runtime/ask_about_mahen_agentcore-OQ0yZ9D9E0' codebuild_id='bedrock-agentcore-ask_about_mahen_agentcore-builder:09c3a035-5b9c-4777-a56d-06ff1b6b45f8' build_output=None

# %% [markdown]
# checking Runtime Status

# %%
import time
status_response = agentcore_runtime.status()
status = status_response.endpoint['status']
end_status = ['READY', 'CREATE_FAILED', 'DELETE_FAILED', 'UPDATE_FAILED']
while status not in end_status:
    time.sleep(10)
    status_response = agentcore_runtime.status()
    status = status_response.endpoint['status']
    print(status)
status
# Out:
# Retrieved Bedrock AgentCore status for: ask_about_mahen_agentcore
# 'READY'
